# %%
import pandas as pd
import numpy as np

# %%
file_path = r'C:\Users\DELL\OneDrive\Documents\restaurant_customer_satisfaction.csv'
df = pd.read_csv(file_path)
df
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0            654   35    Male   83380         Weekly     27.829142
# 1            655   19    Male   43623         Rarely    115.408622
# 2            656   41  Female   83737         Weekly    106.693771
# 3            657   43    Male   96768         Rarely     43.508508
# 4            658   55  Female   67937        Monthly    148.084627
# ...          ...  ...     ...     ...            ...           ...
# 1495        2149   39    Male  114857        Monthly    163.015254
# 1496        2150   37  Female  133506         Weekly    190.991911
# 1497        2151   46    Male  119159        Monthly    150.088604
# 1498        2152   24    Male   27970         Weekly    196.363626
# 1499        2153   51    Male  148333         Weekly    171.119498
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0             Chinese   Breakfast          3       Business  Takeaway
# ...

# %%
df.describe()
# Out:
#               654           35          83380  27.829142002481408  \
# count  1499.00000  1499.000000    1499.000000         1499.000000
# mean   1404.00000    43.837892   85923.585724          105.710925
# std     432.86834    14.970412   38195.737800           52.360704
# min     655.00000    18.000000   20012.000000           10.306127
# 25%    1029.50000    31.500000   52430.000000           62.424746
# 50%    1404.00000    44.000000   85820.000000          104.798136
# 75%    1778.50000    57.000000  119159.500000          148.667223
# max    2153.00000    69.000000  149875.000000          199.973527
#
#                  3            0            1          1.1  43.52392853444247  \
# count  1499.000000  1499.000000  1499.000000  1499.000000        1499.000000
# mean      5.036691     0.296865     0.404937     0.479653          30.154637
# std       2.559177     0.457029     0.491044     0.499753          17.216466
# ...

# %%
df.Income.quantile(0.75)
# Out:
# 119159.25

# %%
df.Income.quantile(0.45)
# Out:
# 79432.25

# %%
df.Income.quantile(1)
# Out:
# 149875.0

# %%
percentile_99 = df.Income.quantile(0.99)
percentile_99
# Out:
# 149118.24

# %%
df_no_outlier = df[df.Income<=percentile_99]
df_no_outlier
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0            654   35    Male   83380         Weekly     27.829142
# 1            655   19    Male   43623         Rarely    115.408622
# 2            656   41  Female   83737         Weekly    106.693771
# 3            657   43    Male   96768         Rarely     43.508508
# 4            658   55  Female   67937        Monthly    148.084627
# ...          ...  ...     ...     ...            ...           ...
# 1495        2149   39    Male  114857        Monthly    163.015254
# 1496        2150   37  Female  133506         Weekly    190.991911
# 1497        2151   46    Male  119159        Monthly    150.088604
# 1498        2152   24    Male   27970         Weekly    196.363626
# 1499        2153   51    Male  148333         Weekly    171.119498
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0             Chinese   Breakfast          3       Business  Takeaway
# ...

# %%
df['Income'][3] = np.NaN
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17128\2841357448.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Income'][3,4,5,6] = np.NaN
# ...

# %%
df
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0            654   35    Male   83380         Weekly     27.829142
# 1            655   19    Male   43623         Rarely    115.408622
# 2            656   41  Female   83737         Weekly    106.693771
# 3            657   43    Male   96768         Rarely     43.508508
# 4            658   55  Female   67937        Monthly    148.084627
# ...          ...  ...     ...     ...            ...           ...
# 1495        2149   39    Male  114857        Monthly    163.015254
# 1496        2150   37  Female  133506         Weekly    190.991911
# 1497        2151   46    Male  119159        Monthly    150.088604
# 1498        2152   24    Male   27970         Weekly    196.363626
# 1499        2153   51    Male  148333         Weekly    171.119498
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0             Chinese   Breakfast          3       Business  Takeaway
# ...

# %%
df
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0            654   35    Male   83380         Weekly     27.829142
# 1            655   19    Male   43623         Rarely    115.408622
# 2            656   41  Female   83737         Weekly    106.693771
# 3            657   43    Male   96768         Rarely     43.508508
# 4            658   55  Female   67937        Monthly    148.084627
# ...          ...  ...     ...     ...            ...           ...
# 1495        2149   39    Male  114857        Monthly    163.015254
# 1496        2150   37  Female  133506         Weekly    190.991911
# 1497        2151   46    Male  119159        Monthly    150.088604
# 1498        2152   24    Male   27970         Weekly    196.363626
# 1499        2153   51    Male  148333         Weekly    171.119498
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0             Chinese   Breakfast          3       Business  Takeaway
# ...

# %%
df['VisitFrequency'][3] = np.NaN
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17128\2948688279.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['VisitFrequency'][3] = np.NaN
# ...

# %%
df
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0            654   35    Male   83380         Weekly     27.829142
# 1            655   19    Male   43623         Rarely    115.408622
# 2            656   41  Female   83737         Weekly    106.693771
# 3            657   43    Male   96768            NaN     43.508508
# 4            658   55  Female   67937        Monthly    148.084627
# ...          ...  ...     ...     ...            ...           ...
# 1495        2149   39    Male  114857        Monthly    163.015254
# 1496        2150   37  Female  133506         Weekly    190.991911
# 1497        2151   46    Male  119159        Monthly    150.088604
# 1498        2152   24    Male   27970         Weekly    196.363626
# 1499        2153   51    Male  148333         Weekly    171.119498
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0             Chinese   Breakfast          3       Business  Takeaway
# ...

# %%
df['Income'][3] = np.NaN
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17128\3686263634.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Income'][3] = np.NaN
#       CustomerID  Age  Gender    Income VisitFrequency  AverageSpend  \
# 0            654   35    Male   83380.0         Weekly     27.829142
# 1            655   19    Male   43623.0         Rarely    115.408622
# 2            656   41  Female   83737.0         Weekly    106.693771
# 3            657   43    Male       NaN            NaN     43.508508
# 4            658   55  Female   67937.0        Monthly    148.084627
# ...          ...  ...     ...       ...            ...           ...
# 1495        2149   39    Male  114857.0        Monthly    163.015254
# 1496        2150   37  Female  133506.0         Weekly    190.991911
# ...

# %%
df.Income.mean()
# Out:
# 85914.65443629086

# %%
df_new = df.fillna(df.Income.mean())
df_new
# Out:
#       CustomerID  Age  Gender         Income VisitFrequency  AverageSpend  \
# 0            654   35    Male   83380.000000         Weekly     27.829142
# 1            655   19    Male   43623.000000         Rarely    115.408622
# 2            656   41  Female   83737.000000         Weekly    106.693771
# 3            657   43    Male   85914.654436   85914.654436     43.508508
# 4            658   55  Female   67937.000000        Monthly    148.084627
# ...          ...  ...     ...            ...            ...           ...
# 1495        2149   39    Male  114857.000000        Monthly    163.015254
# 1496        2150   37  Female  133506.000000         Weekly    190.991911
# 1497        2151   46    Male  119159.000000        Monthly    150.088604
# 1498        2152   24    Male   27970.000000         Weekly    196.363626
# 1499        2153   51    Male  148333.000000         Weekly    171.119498
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# ...
